# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathi32/practzero/blob/main/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# exp 0 - intro to python
# 25070123129

# %%
# sakshi
print("sakshirathi")
# Out:
# sakshirathi

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="sakshi rathi"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# sakshi rathi
